# %%
# The code was removed by DSX for sharing.
# Out:
#    mpg  cylinders  engine  horsepower  weight  acceleration  year    origin  \
# 0   18          8     307         130    3504          12.0    70  American
# 1   15          8     350         165    3693          11.5    70  American
# 2   18          8     318         150    3436          11.0    70  American
# 3   16          8     304         150    3433          12.0    70  American
# 4   17          8     302         140    3449          10.5    70  American
#
#                         name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
import brunel

# %%
# %brunel data('df_data_1') x(mpg) y(horsepower) color (origin) :: width=800
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/0334df40-d744-493d-8b25-423d969da91c/nbextensions/brunel_ext/Brunel.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/0334df40-d744-493d-8b25-423d969da91c/nbextensions/brunel_ext/sumoselect/sumoselect.css">
#
# <style>
#
# </style>
#
# ...
